# %%
import networkx as nx
import pickle
import pandas as pd

# %%
from google.colab import drive
import os

drive.mount('/content/drive')

shared_folder = '/content/drive/MyDrive/Ariya Narayanasamy/Data/Pickle Saves'
os.chdir(shared_folder)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
with open('tm_graph.pickle', 'rb') as handle:
    G = pickle.load(handle)

# %%
betweenness = nx.betweenness_centrality(G)

# %%
data = [{
    'station_name': node, 'betweenness_centrality': centrality, 'lines': list(G.nodes()[node]['serviced_lines'].keys())
} for node, centrality in betweenness.items()]
df = pd.DataFrame(data)

# %%
df = df.sort_values(by='betweenness_centrality', ascending=False)
df.reset_index(drop=True, inplace=True)
df
# Out:
#     station_name  betweenness_centrality  \
# 0       Otemachi                0.416414
# 1     Kudanshita                0.327183
# 2      Iidabashi                0.323115
# 3      Nagatacho                0.237238
# 4        Yotsuya                0.225012
# ..           ...                     ...
# 139     Gaiemmae                0.000000
# 140      Shibuya                0.000000
# 141      Wakoshi                0.000000
# 142   Kita-ayase                0.000000
# 143    Shin-kiba                0.000000
#
#                                       lines
# 0    [Chiyoda, Hanzomon, Marunouchi, Tozai]
# 1                         [Hanzomon, Tozai]
# 2               [Namboku, Tozai, Yurakucho]
# 3            [Hanzomon, Namboku, Yurakucho]
# 4                     [Marunouchi, Namboku]
# ..                                      ...
# 139                                 [Ginza]
# 140           [Fukutoshin, Ginza, Hanzomon]
# 141                 [Fukutoshin, Yurakucho]
# ...

# %%
df.to_csv('centrality_data.csv', index=False)
